# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats

import requests
import time
from scrapy.selector import Selector
from scrapy.http import HtmlResponse
from selenium import webdriver
from bs4 import BeautifulSoup
import json
df = pd.read_csv('/Users/amos/Desktop/DSI-SF-2-amoskim25/nba_capstone/nbastats/game_logs2005-06.csv')

# %%
df.columns
# Out:
# Index([u'Unnamed: 0', u'SEASON_ID', u'PLAYER_ID', u'PLAYER_NAME',
#        u'TEAM_ABBREVIATION', u'TEAM_NAME', u'GAME_ID', u'GAME_DATE',
#        u'MATCHUP', u'WL', u'MIN', u'FGM', u'FGA', u'FG_PCT', u'FG3M', u'FG3A',
#        u'FG3_PCT', u'FTM', u'FTA', u'FT_PCT', u'OREB', u'DREB', u'REB', u'AST',
#        u'STL', u'BLK', u'TOV', u'PF', u'PTS', u'PLUS_MINUS',
#        u'VIDEO_AVAILABLE'],
#       dtype='object')

# %%
df.shape
# Out:
# (24917, 31)

# %%
50 * 25000
# Out:
# 1250000

# %%
df.head()
# Out:
#    Unnamed: 0  SEASON_ID  PLAYER_ID    PLAYER_NAME TEAM_ABBREVIATION  \
# 0           0      22005        977    Kobe Bryant               LAL
# 1           1      22005        977    Kobe Bryant               LAL
# 2           2      22005        947  Allen Iverson               PHI
# 3           3      22005       2544   LeBron James               CLE
# 4           4      22005        977    Kobe Bryant               LAL
#
#              TEAM_NAME   GAME_ID   GAME_DATE      MATCHUP WL       ...         \
# 0   Los Angeles Lakers  20500591  2006-01-22  LAL vs. TOR  W       ...
# 1   Los Angeles Lakers  20500359  2005-12-20  LAL vs. DAL  W       ...
# 2   Philadelphia 76ers  20500371  2005-12-23    PHI @ ATL  L       ...
# 3  Cleveland Cavaliers  20500287  2005-12-10    CLE @ MIL  L       ...
# 4   Los Angeles Lakers  20501130  2006-04-07    LAL @ PHX  L       ...
#
#    DREB  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  VIDEO_AVAILABLE
# ...

# %%
df.columns
# Out:
# Index([u'Unnamed: 0', u'SEASON_ID', u'PLAYER_ID', u'PLAYER_NAME',
#        u'TEAM_ABBREVIATION', u'TEAM_NAME', u'GAME_ID', u'GAME_DATE',
#        u'MATCHUP', u'WL', u'MIN', u'FGM', u'FGA', u'FG_PCT', u'FG3M', u'FG3A',
#        u'FG3_PCT', u'FTM', u'FTA', u'FT_PCT', u'OREB', u'DREB', u'REB', u'AST',
#        u'STL', u'BLK', u'TOV', u'PF', u'PTS', u'PLUS_MINUS',
#        u'VIDEO_AVAILABLE'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0', 'VIDEO_AVAILABLE'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-b5e34ccbd381> in <module>()
# ----> 1 df.drop(['Unnamed: 0', 'VIDEO_AVAILABLE'], axis=1, inplace=True)
#
# /Users/amos/anaconda/envs/dsi/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    1875                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1876             else:
# -> 1877                 new_axis = axis.drop(labels, errors=errors)
#    1878             dropped = self.reindex(**{axis_name: new_axis})
#    1879             try:
#
# /Users/amos/anaconda/envs/dsi/lib/python2.7/site-packages/pandas/indexes/base.pyc in drop(self, labels, errors)
#    3049             if errors != 'ignore':
#    3050                 raise ValueError('labels %s not contained in axis' %
# -> 3051                                  labels[mask])
# ...

# %%
df.head()
# Out:
#    SEASON_ID  PLAYER_ID PLAYER_NAME TEAM_ABBREVIATION        TEAM_NAME  \
# 0      21955      77847  Bob Pettit               STL  St. Louis Hawks
# 1      21955      77847  Bob Pettit               STL  St. Louis Hawks
# 2      21955      77847  Bob Pettit               STL  St. Louis Hawks
# 3      21955      76243  Carl Braun               NYK  New York Knicks
# 4      21955      77847  Bob Pettit               STL  St. Louis Hawks
#
#     GAME_ID   GAME_DATE      MATCHUP WL  MIN       ...         DREB  REB  AST  \
# 0  25500239  1956-02-24  STL vs. SYR  W    0       ...          NaN  NaN  NaN
# 1  25500094  1955-12-27  STL vs. BOS  L    0       ...          NaN  NaN  NaN
# 2  25500274  1956-03-09  STL vs. MNL  W    0       ...          NaN  NaN  NaN
# 3  25500246  1956-02-27  NYK vs. STL  W    0       ...          NaN  NaN  NaN
# 4  25500279  1956-03-11    STL @ BOS  W    0       ...          NaN  NaN  NaN
#
#    STL  BLK  TOV  PF  PTS  PLUS_MINUS  VIDEO_AVAILABLE
# ...

# %%
kobe = df[df['PLAYER_NAME']== 'Kobe Bryant']

# %%
kobe.head()
# Out:
#    Unnamed: 0  SEASON_ID  PLAYER_ID  PLAYER_NAME TEAM_ABBREVIATION  \
# 0           0      22005        977  Kobe Bryant               LAL
# 1           1      22005        977  Kobe Bryant               LAL
# 4           4      22005        977  Kobe Bryant               LAL
# 7           7      22005        977  Kobe Bryant               LAL
# 9           9      22005        977  Kobe Bryant               LAL
#
#             TEAM_NAME   GAME_ID   GAME_DATE      MATCHUP WL       ...         \
# 0  Los Angeles Lakers  20500591  2006-01-22  LAL vs. TOR  W       ...
# 1  Los Angeles Lakers  20500359  2005-12-20  LAL vs. DAL  W       ...
# 4  Los Angeles Lakers  20501130  2006-04-07    LAL @ PHX  L       ...
# 7  Los Angeles Lakers  20500563  2006-01-19    LAL @ SAC  L       ...
# 9  Los Angeles Lakers  20501185  2006-04-14  LAL vs. POR  W       ...
#
#    DREB  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  VIDEO_AVAILABLE
# ...

# %%
kobe.PLUS_MINUS.mean()
# Out:
# 3.9875

# %%
df[df.PLUS_MINUS < 0].head()
# Out:
#     Unnamed: 0  SEASON_ID  PLAYER_ID    PLAYER_NAME TEAM_ABBREVIATION  \
# 2            2      22005        947  Allen Iverson               PHI
# 3            3      22005       2544   LeBron James               CLE
# 4            4      22005        977    Kobe Bryant               LAL
# 7            7      22005        977    Kobe Bryant               LAL
# 10          10      22005       1718    Paul Pierce               BOS
#
#               TEAM_NAME   GAME_ID   GAME_DATE      MATCHUP WL  \
# 2    Philadelphia 76ers  20500371  2005-12-23    PHI @ ATL  L
# 3   Cleveland Cavaliers  20500287  2005-12-10    CLE @ MIL  L
# 4    Los Angeles Lakers  20501130  2006-04-07    LAL @ PHX  L
# 7    Los Angeles Lakers  20500563  2006-01-19    LAL @ SAC  L
# 10       Boston Celtics  20500767  2006-02-15  BOS vs. CLE  L
#
#          ...         DREB  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  \
# 2        ...            6    6    5    2    0    0   0   53          -5
# ...

# %%
plus_minus_avg = df.groupby(['PLAYER_NAME'])[['PLUS_MINUS']].mean().reset_index()

# %%
plus_minus_avg.sort_values('PLUS_MINUS', ascending=False)
# Out:
#             PLAYER_NAME  PLUS_MINUS
# 417     Tayshaun Prince    7.878049
# 359     Rasheed Wallace    7.675000
# 45          Ben Wallace    7.292683
# 82     Chauncey Billups    7.259259
# 404    Slava Medvedenko    7.000000
# 142         Dwyane Wade    6.493333
# 420          Tim Duncan    6.487500
# 367    Richard Hamilton    6.487500
# 426         Tony Parker    6.387500
# 133       Dirk Nowitzki    6.296296
# 285       Manu Ginobili    6.292308
# 309   Metta World Peace    6.196429
# 54           Boris Diaw    6.037037
# 209         Jason Terry    6.000000
# 413          Steve Nash    5.962025
# 233         Josh Howard    5.338983
# 403        Shawn Marion    5.074074
# 354           Raja Bell    4.658228
# 398    Shaquille O'Neal    4.559322
# 258         Kurt Thomas    4.547170
# 67          Bruce Bowen    4.402439
# 397       Shane Battier    4.382716
# 150         Eddie Jones    4.240000
# 439        Vince Carter    4.177215
# 68        Bryon Russell    4.000000
# ...

# %%
year = [str(i)+'-'+str(i+1)[2:] for i in range(1946, 2015)]

# %%
# load game_logs, and remove 'Unnamed: 0', 'VIDEO_AVAILABLE'
for y in year[:10]:
    print y
    csv = '/Users/amos/Desktop/DSI-SF-2-amoskim25/nba_capstone/nbastats/game_logs%s.csv' % y
    df = pd.read_csv(csv)
    df.drop(['Unnamed: 0', 'VIDEO_AVAILABLE'], axis=1, inplace=True)
    print df.head()
    print '==================================='
# Out:
# 1946-47
#    SEASON_ID  PLAYER_ID      PLAYER_NAME TEAM_ABBREVIATION  \
# 0      21946      76764        Joe Fulks               PHW
# 1      21946      77471    Donald Martin               PRO
# 2      21946      78443  Michael Wallace               HUS
# 3      21946      76764        Joe Fulks               PHW
# 4      21946      76764        Joe Fulks               PHW
#
#                  TEAM_NAME   GAME_ID   GAME_DATE      MATCHUP WL  MIN  \
# 0    Philadelphia Warriors  24600157  1947-01-14    PHW @ HUS  W    0
# 1  Providence Steamrollers  24600147  1947-01-09  PRO vs. CLR  W    0
# 2          Toronto Huskies  24600195  1947-01-31  HUS vs. WAS  W    0
# 3    Philadelphia Warriors  24600210  1947-02-06  PHW vs. HUS  W    0
# 4    Philadelphia Warriors  24600069  1946-12-03  PHW vs. PRO  W    0
#
#       ...      OREB  DREB  REB  AST  STL  BLK  TOV   PF  PTS  PLUS_MINUS
# 0     ...       NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   41         NaN
# ...
