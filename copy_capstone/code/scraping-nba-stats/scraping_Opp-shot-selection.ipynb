# %% [markdown]
# Opponent shot selection
# http://stats.nba.com/league/player/#!/oppshooting/

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats

import requests
import time
from scrapy.selector import Selector
from scrapy.http import HtmlResponse
from selenium import webdriver
from bs4 import BeautifulSoup
import json

chromedriver = "/Users/amos/Desktop/chromedriver"

# %%
# opens selenium webdriver
browser = webdriver.Chrome(executable_path= chromedriver)

# %%
browser.get('http://stats.nba.com/league/player/#!/oppshooting/')
#json html format
HTML_logs = browser.page_source
years = Selector(text=HTML_logs).xpath("//select[@name='Season']/option/text()").extract()
years = years[1:]

# %%
stats_url = 'http://stats.nba.com/stats/leaguedashplayershotlocations?College=&Conference=\
&Country=&DateFrom=&DateTo=&DistanceRange=5ft+Range&Division=&DraftPick=&DraftYear=&GameScope=&\
GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Opponent&Month=0&\
OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode=PerGame&Period=0&PlayerExperience=&\
PlayerPosition=&PlusMinus=N&Rank=N&Season=%s&SeasonSegment=&SeasonType=Regular+Season&\
ShotClockRange=&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='

# %%
# Find Header or column names
link = stats_url % '2001-02'
browser.get(link)
HTML = browser.page_source
soup = BeautifulSoup(HTML, 'lxml')
text = soup.findAll('pre')[0].getText().encode('utf-8')
json_text = json.loads(text)
shot_ranges = json_text['resultSets']['headers'][0]['columnNames']
new_ranges = [rang.replace('-','_').replace('.','').replace(' ', '').
                  replace('+','above').lower() for rang in shot_ranges]
columns = json_text['resultSets']['headers'][1]['columnNames']
fg_list = ['FGM', 'FGA', 'FG_PCT']
headers = columns[:5]
for rang in new_ranges:
    for f in fg_list:
        headers.append('opp_' + rang + '_'+ f)
headers
# Out:
# [u'PLAYER_ID',
#  u'PLAYER_NAME',
#  u'TEAM_ID',
#  u'TEAM_ABBREVIATION',
#  u'AGE',
#  u'opp_lessthan5ft_FGM',
#  u'opp_lessthan5ft_FGA',
#  u'opp_lessthan5ft_FG_PCT',
#  u'opp_5_9ft_FGM',
#  u'opp_5_9ft_FGA',
#  u'opp_5_9ft_FG_PCT',
#  u'opp_10_14ft_FGM',
#  u'opp_10_14ft_FGA',
#  u'opp_10_14ft_FG_PCT',
#  u'opp_15_19ft_FGM',
#  u'opp_15_19ft_FGA',
#  u'opp_15_19ft_FG_PCT',
#  u'opp_20_24ft_FGM',
#  u'opp_20_24ft_FGA',
#  u'opp_20_24ft_FG_PCT',
#  u'opp_25_29ft_FGM',
#  u'opp_25_29ft_FGA',
#  u'opp_25_29ft_FG_PCT',
#  u'opp_30_34ft_FGM',
#  u'opp_30_34ft_FGA',
#  u'opp_30_34ft_FG_PCT',
#  u'opp_35_39ft_FGM',
#  u'opp_35_39ft_FGA',
#  u'opp_35_39ft_FG_PCT',
#  u'opp_40aboveft_FGM',
#  u'opp_40aboveft_FGA',
#  u'opp_40aboveft_FG_PCT']

# %%
headers[8:]
# Out:
# [u'opp_5_9ft_FGM',
#  u'opp_5_9ft_FGA',
#  u'opp_5_9ft_FG_PCT',
#  u'opp_10_14ft_FGM',
#  u'opp_10_14ft_FGA',
#  u'opp_10_14ft_FG_PCT',
#  u'opp_15_19ft_FGM',
#  u'opp_15_19ft_FGA',
#  u'opp_15_19ft_FG_PCT',
#  u'opp_20_24ft_FGM',
#  u'opp_20_24ft_FGA',
#  u'opp_20_24ft_FG_PCT',
#  u'opp_25_29ft_FGM',
#  u'opp_25_29ft_FGA',
#  u'opp_25_29ft_FG_PCT',
#  u'opp_30_34ft_FGM',
#  u'opp_30_34ft_FGA',
#  u'opp_30_34ft_FG_PCT',
#  u'opp_35_39ft_FGM',
#  u'opp_35_39ft_FGA',
#  u'opp_35_39ft_FG_PCT',
#  u'opp_40aboveft_FGM',
#  u'opp_40aboveft_FGA',
#  u'opp_40aboveft_FG_PCT']

# %%
# Create Data frame of each regular season opponents player stats from 1996-2016 and save to csv file.

for year in years:
    print year
    link = stats_url % year
    #selenium browser opens link
    browser.get(link)
    HTML = browser.page_source
    soup = BeautifulSoup(HTML, "lxml")
    get_text = soup.findAll('pre')[0].getText().encode('utf-8')
    json_text = json.loads(get_text)

    
    df = pd.DataFrame(json_text['resultSets']['rowSet'], columns=headers) 
    df.drop(headers[8:], axis=1, inplace=True)
    df['SEASON'] = year[:4]
    save_csv = '/Users/amos/Desktop/DSI-SF-2-amoskim25/copy_capstone/datasets/update_opponent_shot_range/update_opp_shot_range%s.csv' % year
    df.to_csv(save_csv)
#     time.sleep(5*np.random.rand())
# Out:
# 2015-16
# 2014-15
# 2013-14
# 2012-13
# 2011-12
# 2010-11
# 2009-10
# 2008-09
# 2007-08
# 2006-07
# 2005-06
# 2004-05
# 2003-04
# 2002-03
# 2001-02
# 2000-01
# 1999-00
# 1998-99
# 1997-98
# 1996-97

# %%
pd.read_csv('../../datasets/update_opponent_shot_range/update_opp_shot_range1997-98.csv')
# Out:
#      Unnamed: 0  PLAYER_ID         PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  \
# 0             0        920          A.C. Green  1610612742               DAL
# 1             1        243         Aaron McKie  1610612755               PHI
# 2             2       1425      Aaron Williams  1610612760               SEA
# 3             3        228          Adam Keefe  1610612762               UTA
# 4             4       1502        Adonal Foyle  1610612744               GSW
# 5             5        154     Adrian Caldwell  1610612742               DAL
# 6             6        673      Alan Henderson  1610612737               ATL
# 7             7        275       Allan Houston  1610612752               NYK
# 8             8        947       Allen Iverson  1610612755               PHI
# 9             9        297     Alonzo Mourning  1610612748               MIA
# 10           10        175        Alton Lister  1610612757               POR
# 11           11       1541      Alvin Williams  1610612761               TOR
# 12           12        692     Andrew DeClercq  1610612738               BOS
# 13           13        457         Andrew Lang  1610612749               MIL
# 14           14        358   Anfernee Hardaway  1610612753               ORL
# 15           15        194       Anthony Bowie  1610612752               NYK
# 16           16        924    Anthony Goldwire  1610612743               DEN
# 17           17       1533     Anthony Johnson  1610612758               SAC
# 18           18        193       Anthony Mason  1610612766               CHH
# 19           19        292      Anthony Miller  1610612737               ATL
# 20           20       1515      Anthony Parker  1610612755               PHI
# 21           21        324      Anthony Peeler  1610612750               MIN
# 22           22        156        Antoine Carr  1610612762               UTA
# 23           23        952      Antoine Walker  1610612738               BOS
# 24           24       1498     Antonio Daniels  1610612763               VAN
# 25           25        213       Antonio Davis  1610612754               IND
# 26           26        226        Antonio Lang  1610612748               MIA
# 27           27        686     Antonio McDyess  1610612756               PHX
# 28           28        288       Armen Gilliam  1610612749               MIL
# 29           29        717     Arvydas Sabonis  1610612757               POR
# ..          ...        ...                 ...         ...               ...
# 409         409        434          Tony Dumas  1610612739               CLE
# 410         410       1108         Tony Farmer  1610612766               CHH
# 411         411        763     Tony Massenburg  1610612763               VAN
# 412         412        380          Tony Smith  1610612749               MIL
# 413         413       1503       Tracy McGrady  1610612761               TOR
# 414         414        145        Tracy Murray  1610612764               WAS
# 415         415        696         Travis Best  1610612754               IND
# 416         416        969       Travis Knight  1610612738               BOS
# 417         417       1576     Travis Williams  1610612766               CHH
# 418         418       1607         Troy Hudson  1610612762               UTA
# 419         419        895       Tyrone Corbin  1610612737               ATL
# 420         420        238         Tyrone Hill  1610612749               MIL
# 421         421        721          Tyus Edney  1610612738               BOS
# 422         422        137      Vernon Maxwell  1610612766               CHH
# 423         423        452           Vin Baker  1610612760               SEA
# 424         424        355       Vincent Askew  1610612757               POR
# 425         425        219     Vinny Del Negro  1610612759               SAS
# 426         426        958    Vitaly Potapenko  1610612739               CLE
# 427         427        124         Vlade Divac  1610612766               CHH
# 428         428        702       Voshon Lenard  1610612748               MIA
# 429         429       1005       Walt Williams  1610612757               POR
# 430         430        962      Walter McCarty  1610612738               BOS
# 431         431        445       Wesley Person  1610612739               CLE
# 432         432        781         Will Perdue  1610612759               SAS
# 433         433       1061  William Cunningham  1610612755               PHI
# 434         434        416       Willie Burton  1610612759               SAS
# 435         435       1365     Xavier McDaniel  1610612751               NJN
# 436         436        212          Yinka Dare  1610612751               NJN
# 437         437        440           Zan Tabak  1610612738               BOS
# 438         438        980  Zydrunas Ilgauskas  1610612739               CLE
#
#       AGE  opp_lessthan5ft_FGM  opp_lessthan5ft_FGA  opp_lessthan5ft_FG_PCT  \
# 0    34.0                 12.2                 20.4                   0.600
# 1    25.0                  6.1                 10.8                   0.562
# 2    26.0                  4.5                  7.5                   0.599
# 3    28.0                  8.0                 13.6                   0.583
# 4    23.0                  4.1                  7.1                   0.567
# 5    31.0                  1.0                  1.0                   1.000
# 6    25.0                 10.2                 18.2                   0.562
# 7    27.0                  9.9                 16.8                   0.585
# 8    23.0                 13.3                 22.7                   0.586
# 9    28.0                  8.4                 16.8                   0.498
# 10   39.0                  0.9                  1.9                   0.462
# 11   23.0                  6.8                 12.8                   0.532
# 12   25.0                  7.9                 12.7                   0.621
# 13   32.0                  4.0                  6.2                   0.646
# 14   26.0                 11.1                 19.4                   0.571
# 15   34.0                  2.7                  4.2                   0.632
# 16   26.0                  9.7                 15.1                   0.643
# 17   23.0                 11.3                 18.7                   0.606
# 18   31.0                 13.5                 22.2                   0.608
