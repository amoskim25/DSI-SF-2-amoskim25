# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 6:  Web Scraping
# ### Finding Underpriced RVs on Craigslist
#
# ![](https://snag.gy/WrdUMx.jpg)

# %% [markdown]
# In this project we will be practicing our web scraping skills.  You can use Scrapy or Python requests in order to complete this project.  It may be helpful to write some prototype code in this notebook to test your assumptions, then move it into a Python file that can be run from the command line.
#
# > In order to run code from the command line, instead of the notebook, you just need to save your code to a file (with a .py extension), and run it using the Python interpreter:<br><br>
# > `python my_file.py`
#
# You will be building a process to scrape a single category of search results on Craigslist, that can easily be applied to other categories by changing the search terms.  The main goal is to be able to target and scrape a single page given a set of parameters.
#
# **If you use Scrapy, provide your code in a folder.**

# %% [markdown]
# ## Import your libraries for scrapy / requests / pandas / numpy / etc
# Setup whichever libraries you need. Review past material for reference.

# %% [markdown]
# http://localhost:8888/notebooks/practice/week-04/3.2-web-scraping-1/slides/1.3-web_scraping_1-dave-solutions.ipynb

# %%
import numpy as np
import requests
from scrapy.selector import Selector
from scrapy.http import HtmlResponse

import pandas as pd

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1.  Scrape for the largest US cities (non-exhaustive list)
# Search, research, and scrape Wikipedia for a list of the largest US cities.  There are a few sources but find one that is in a nice table.  We don't want all cities, just signifficant cities.  Examine your source.  Look for what can be differentiable.
#
# - Use requests
# - Build XPath query(ies)
# - Extract to a list
# - Clean your list

# %%
req = requests.get('https://en.wikipedia.org/wiki/List_of_United_States_cities_by_population')
res = Selector(text=req.text)

# %%
rows = res.xpath("//table[@class='wikitable sortable'][1]//tr/td[2]//a/text()").extract()
rows
# for row in row:
#     print row.xpath("td").extract()
# Out:
# [u'New York',
#  u'[6]',
#  u'Los Angeles',
#  u'Chicago',
#  u'Houston',
#  u'[7]',
#  u'Philadelphia',
#  u'[8]',
#  u'Phoenix',
#  u'San Antonio',
#  u'San Diego',
#  u'Dallas',
#  u'San Jose',
#  u'Austin',
#  u'Jacksonville',
#  u'[9]',
#  u'San Francisco',
#  u'[10]',
#  u'Indianapolis',
#  u'[11]',
#  u'Columbus',
#  u'Fort Worth',
#  u'Charlotte',
#  u'Seattle',
#  u'Denver',
#  u'[12]',
#  u'El Paso',
#  u'Detroit',
#  u'Washington',
#  u'[13]',
#  u'Boston',
#  u'Memphis',
#  u'Nashville',
#  u'[14]',
#  u'Portland',
#  u'Oklahoma City',
#  u'Las Vegas',
#  u'Baltimore',
#  u'[15]',
#  u'Louisville',
#  u'[16]',
#  u'Milwaukee',
#  u'Albuquerque',
#  u'Tucson',
#  u'Fresno',
#  u'Sacramento',
#  u'Kansas City',
#  u'Long Beach',
#  u'Mesa',
#  u'Atlanta',
#  u'Colorado Springs',
#  u'Virginia Beach',
#  u'[15]',
#  u'Raleigh',
#  u'Omaha',
#  u'Miami',
#  u'Oakland',
#  u'Minneapolis',
#  u'Tulsa',
#  u'Wichita',
#  u'New Orleans',
#  u'[17]',
#  u'Arlington',
#  u'Cleveland',
#  u'Bakersfield',
#  u'Tampa',
#  u'Aurora',
#  u'Honolulu',
#  u'[2]',
#  u'Anaheim',
#  u'Santa Ana',
#  u'Corpus Christi',
#  u'Riverside',
#  u'St. Louis',
#  u'[15]',
#  u'Lexington',
#  u'[18]',
#  u'Stockton',
#  u'Pittsburgh',
#  u'Saint Paul',
#  u'Anchorage',
#  u'[19]',
#  u'Cincinnati',
#  u'Henderson',
#  u'Greensboro',
#  u'Plano',
#  u'Newark',
#  u'Toledo',
#  u'Lincoln',
#  u'Orlando',
#  u'Chula Vista',
#  u'Jersey City',
#  u'Chandler',
#  u'Fort Wayne',
#  u'Buffalo',
#  u'Durham',
#  u'St. Petersburg',
#  u'Irvine',
#  u'Laredo',
#  u'Lubbock',
#  u'Madison',
#  u'Gilbert',
#  u'[20]',
#  u'Norfolk',
#  u'[15]',
#  u'Reno',
#  u'Winston\u2013Salem',
#  u'Glendale',
#  u'Hialeah',
#  u'Garland',
#  u'Scottsdale',
#  u'Irving',
#  u'Chesapeake',
#  u'[15]',
#  u'North Las Vegas',
#  u'Fremont',
#  u'Baton Rouge',
#  u'[21]',
#  u'Richmond',
#  u'[15]',
#  u'Boise',
#  u'[22]',
#  u'San Bernardino',
#  u'Spokane',
#  u'Birmingham',
#  u'Modesto',
#  u'Des Moines',
#  u'Rochester',
#  u'Tacoma',
#  u'Fontana',
#  u'Oxnard',
#  u'Moreno Valley',
#  u'Fayetteville',
#  u'Huntington Beach',
#  u'Yonkers',
#  u'Glendale',
#  u'Aurora',
#  u'Montgomery',
#  u'Columbus',
#  u'[23]',
#  u'Amarillo',
#  u'Little Rock',
#  u'Akron',
#  u'Shreveport',
#  u'Augusta',
#  u'[24]',
#  u'Grand Rapids',
#  u'Mobile',
#  u'Salt Lake City',
#  u'Huntsville',
#  u'Tallahassee',
#  u'Grand Prairie',
#  u'Overland Park',
#  u'Knoxville',
#  u'Worcester',
#  u'Brownsville',
#  u'Newport News',
#  u'[15]',
#  u'Santa Clarita',
#  u'Port St. Lucie',
#  u'Providence',
#  u'Fort Lauderdale',
#  u'Chattanooga',
#  u'Tempe',
#  u'Oceanside',
#  u'Garden Grove',
#  u'Rancho Cucamonga',
#  u'Cape Coral',
#  u'Santa Rosa',
#  u'Vancouver',
#  u'Sioux Falls',
#  u'Peoria',
#  u'Ontario',
#  u'Jackson',
#  u'Elk Grove',
#  u'Springfield',
#  u'Pembroke Pines',
#  u'Salem',
#  u'Corona',
#  u'Eugene',
#  u'McKinney',
#  u'Fort Collins',
#  u'Lancaster',
#  u'Cary',
#  u'[25]',
#  u'Palmdale',
#  u'Hayward',
#  u'Salinas',
#  u'Frisco',
#  u'Springfield',
#  u'Pasadena',
#  u'Macon',
#  u'[26]',
#  u'Alexandria',
#  u'[15]',
#  u'Pomona',
#  u'Lakewood',
#  u'Sunnyvale',
#  u'Escondido',
#  u'Kansas City',
#  u'[27]',
#  u'Hollywood',
#  u'Clarksville',
#  u'Torrance',
#  u'Rockford',
#  u'Joliet',
#  u'Paterson',
#  u'Bridgeport',
#  u'Naperville',
#  u'Savannah',
#  u'Mesquite',
#  u'Syracuse',
#  u'Pasadena',
#  u'Orange',
#  u'Fullerton',
#  u'Killeen',
#  u'Dayton',
#  u'McAllen',
#  u'Bellevue',
#  u'Miramar',
#  u'Hampton',
#  u'[15]',
#  u'West Valley City',
#  u'Warren',
#  u'Olathe',
#  u'Columbia',
#  u'Thornton',
#  u'Carrollton',
#  u'Midland',
#  u'Charleston',
#  u'Waco',
#  u'Sterling Heights',
#  u'Denton',
#  u'Cedar Rapids',
#  u'New Haven',
#  u'Roseville',
#  u'Gainesville',
#  u'Visalia',
#  u'Coral Springs',
#  u'Thousand Oaks',
#  u'Elizabeth',
#  u'Stamford',
#  u'Concord',
#  u'Surprise',
#  u'Lafayette',
#  u'[28]',
#  u'Topeka',
#  u'Kent',
#  u'Simi Valley',
#  u'Santa Clara',
#  u'Murfreesboro',
#  u'Hartford',
#  u'Athens',
#  u'[29]',
#  u'Victorville',
#  u'Abilene',
#  u'Vallejo',
#  u'Berkeley',
#  u'Norman',
#  u'Allentown',
#  u'Evansville',
#  u'Columbia',
#  u'Odessa',
#  u'Fargo',
#  u'Beaumont',
#  u'Independence',
#  u'Ann Arbor',
#  u'El Monte',
#  u'Springfield',
#  u'Round Rock',
#  u'Wilmington',
#  u'Arvada',
#  u'Provo',
#  u'Peoria',
#  u'Lansing',
#  u'Downey',
#  u'Carlsbad',
#  u'Costa Mesa',
#  u'Miami Gardens',
#  u'Westminster',
#  u'Clearwater',
#  u'Fairfield',
#  u'Rochester',
#  u'Elgin',
#  u'Temecula',
#  u'West Jordan',
#  u'Inglewood',
#  u'Richardson',
#  u'Lowell',
#  u'Gresham',
#  u'Antioch',
#  u'Cambridge',
#  u'High Point',
#  u'Billings',
#  u'Manchester',
#  u'Murrieta',
#  u'Centennial',
#  u'Richmond',
#  u'Ventura',
#  u'[30]',
#  u'Pueblo',
#  u'Pearland',
#  u'Waterbury',
#  u'West Covina',
#  u'North Charleston',
#  u'Everett',
#  u'College Station',
#  u'Palm Bay',
#  u'Pompano Beach',
#  u'Boulder',
#  u'Norwalk',
#  u'West Palm Beach',
#  u'Broken Arrow',
#  u'Daly City',
#  u'Sandy Springs',
#  u'Burbank',
#  u'Green Bay',
#  u'Santa Maria',
#  u'Wichita Falls',
#  u'Lakeland',
#  u'Clovis',
#  u'Lewisville',
#  u'Tyler',
#  u'El Cajon',
#  u'San Mateo',
#  u'Rialto',
#  u'Edison',
#  u'[31]',
#  u'Davenport',
#  u'Hillsboro',
#  u'Woodbridge',
#  u'[31]',
#  u'Las Cruces',
#  u'South Bend',
#  u'Vista',
#  u'Greeley',
#  u'Davie',
#  u'[32]',
#  u'San Angelo',
#  u'Jurupa Valley',
#  u'Renton']

# %%
funky_ascii = [ row for row in rows if "Winston" in row][0]

# %%
funky_ascii
# Out:
# u'Winston\u2013Salem'

# %%
def is_ascii(s):
    return all(ord(c) != 91 and ord(c) < 128 for c in s)

cities = []
for row in rows:
    if is_ascii(row):
        cities.append(row)
    else:
        continue
        
print cities
# Out:
ids', u'New Haven', u'Roseville', u'Gainesville', u'Visalia', u'Coral Springs', u'Thousand Oaks', u'Elizabeth', u'Stamford', u'Concord', u'Surprise', u'Lafayette', u'Topeka', u'Kent', u'Simi Valley', u'Santa Clara', u'Murfreesboro', u'Hartford', u'Athens', u'Victorville', u'Abilene', u'Vallejo', u'Berkeley', u'Norman', u'Allentown', u'Evansville', u'Columbia', u'Odessa', u'Fargo', u'Beaumont', u'Independence', u'Ann Arbor', u'El Monte', u'Springfield', u'Round Rock', u'Wilmington', u'Arvada', u'Provo', u'Peoria', u'Lansing', u'Downey', u'Carlsbad', u'Costa Mesa', u'Miami Gardens', u'Westminster', u'Clearwater', u'Fairfield', u'Rochester', u'Elgin', u'Temecula', u'West Jordan', u'Inglewood', u'Richardson', u'Lowell', u'Gresham', u'Antioch', u'Cambridge', u'High Point', u'Billings', u'Manchester', u'Murrieta', u'Centennial', u'Richmond', u'Ventura', u'Pueblo', u'Pearland', u'Waterbury', u'West Covina', u'North Charleston', u'Everett', u'College Station', u'Palm Bay', u'Pompano Beach', u'Boulder', u'Norwalk', u'West Palm Beach', u'Broken Arrow', u'Daly City', u'Sandy Springs', u'Burbank', u'Green Bay', u'Santa Maria', u'Wichita Falls', u'Lakeland', u'Clovis', u'Lewisville', u'Tyler', u'El Cajon', u'San Mate ...

# %%
clean_cities = [c.lower().replace(' ','').replace('.','') for c in cities]
print len(clean_cities)
clean_cities = set(clean_cities)
print len(clean_cities)
clean_cities
# Out:
# 303
# 292
# {u'abilene',
#  u'akron',
#  u'albuquerque',
#  u'alexandria',
#  u'allentown',
#  u'amarillo',
#  u'anaheim',
#  u'anchorage',
#  u'annarbor',
#  u'antioch',
#  u'arlington',
#  u'arvada',
#  u'athens',
#  u'atlanta',
#  u'augusta',
#  u'aurora',
#  u'austin',
#  u'bakersfield',
#  u'baltimore',
#  u'batonrouge',
#  u'beaumont',
#  u'bellevue',
#  u'berkeley',
#  u'billings',
#  u'birmingham',
#  u'boise',
#  u'boston',
#  u'boulder',
#  u'bridgeport',
#  u'brokenarrow',
#  u'brownsville',
#  u'buffalo',
#  u'burbank',
#  u'cambridge',
#  u'capecoral',
#  u'carlsbad',
#  u'carrollton',
#  u'cary',
#  u'cedarrapids',
#  u'centennial',
#  u'chandler',
#  u'charleston',
#  u'charlotte',
#  u'chattanooga',
#  u'chesapeake',
#  u'chicago',
#  u'chulavista',
#  u'cincinnati',
#  u'clarksville',
#  u'clearwater',
#  u'cleveland',
#  u'clovis',
#  u'collegestation',
#  u'coloradosprings',
#  u'columbia',
#  u'columbus',
#  u'concord',
#  u'coralsprings',
#  u'corona',
#  u'corpuschristi',
#  u'costamesa',
#  u'dallas',
#  u'dalycity',
#  u'davenport',
#  u'davie',
#  u'dayton',
#  u'denton',
#  u'denver',
#  u'desmoines',
#  u'detroit',
#  u'downey',
#  u'durham',
#  u'edison',
#  u'elcajon',
#  u'elgin',
#  u'elizabeth',
#  u'elkgrove',
#  u'elmonte',
#  u'elpaso',
#  u'escondido',
#  u'eugene',
#  u'evansville',
#  u'everett',
#  u'fairfield',
#  u'fargo',
#  u'fayetteville',
#  u'fontana',
#  u'fortcollins',
#  u'fortlauderdale',
#  u'fortwayne',
#  u'fortworth',
#  u'fremont',
#  u'fresno',
#  u'frisco',
#  u'fullerton',
#  u'gainesville',
#  u'gardengrove',
#  u'garland',
#  u'gilbert',
#  u'glendale',
#  u'grandprairie',
#  u'grandrapids',
#  u'greeley',
#  u'greenbay',
#  u'greensboro',
#  u'gresham',
#  u'hampton',
#  u'hartford',
#  u'hayward',
#  u'henderson',
#  u'hialeah',
#  u'highpoint',
#  u'hillsboro',
#  u'hollywood',
#  u'honolulu',
#  u'houston',
#  u'huntingtonbeach',
#  u'huntsville',
#  u'independence',
#  u'indianapolis',
#  u'inglewood',
#  u'irvine',
#  u'irving',
#  u'jackson',
#  u'jacksonville',
#  u'jerseycity',
#  u'joliet',
#  u'jurupavalley',
#  u'kansascity',
#  u'kent',
#  u'killeen',
#  u'knoxville',
#  u'lafayette',
#  u'lakeland',
#  u'lakewood',
#  u'lancaster',
#  u'lansing',
#  u'laredo',
#  u'lascruces',
#  u'lasvegas',
#  u'lewisville',
#  u'lexington',
#  u'lincoln',
#  u'littlerock',
#  u'longbeach',
#  u'losangeles',
#  u'louisville',
#  u'lowell',
#  u'lubbock',
#  u'macon',
#  u'madison',
#  u'manchester',
#  u'mcallen',
#  u'mckinney',
#  u'memphis',
#  u'mesa',
#  u'mesquite',
#  u'miami',
#  u'miamigardens',
#  u'midland',
#  u'milwaukee',
#  u'minneapolis',
#  u'miramar',
#  u'mobile',
#  u'modesto',
#  u'montgomery',
#  u'morenovalley',
#  u'murfreesboro',
#  u'murrieta',
#  u'naperville',
#  u'nashville',
#  u'newark',
#  u'newhaven',
#  u'neworleans',
#  u'newportnews',
#  u'newyork',
#  u'norfolk',
#  u'norman',
#  u'northcharleston',
#  u'northlasvegas',
#  u'norwalk',
#  u'oakland',
#  u'oceanside',
#  u'odessa',
#  u'oklahomacity',
#  u'olathe',
#  u'omaha',
#  u'ontario',
#  u'orange',
#  u'orlando',
#  u'overlandpark',
#  u'oxnard',
#  u'palmbay',
#  u'palmdale',
#  u'pasadena',
#  u'paterson',
#  u'pearland',
#  u'pembrokepines',
#  u'peoria',
#  u'philadelphia',
#  u'phoenix',
#  u'pittsburgh',
#  u'plano',
#  u'pomona',
#  u'pompanobeach',
#  u'portland',
#  u'portstlucie',
#  u'providence',
#  u'provo',
#  u'pueblo',
#  u'raleigh',
#  u'ranchocucamonga',
#  u'reno',
#  u'renton',
#  u'rialto',
#  u'richardson',
#  u'richmond',
#  u'riverside',
#  u'rochester',
#  u'rockford',
#  u'roseville',
#  u'roundrock',
#  u'sacramento',
#  u'saintpaul',
#  u'salem',
#  u'salinas',
#  u'saltlakecity',
#  u'sanangelo',
#  u'sanantonio',
#  u'sanbernardino',
#  u'sandiego',
#  u'sandysprings',
#  u'sanfrancisco',
#  u'sanjose',
#  u'sanmateo',
#  u'santaana',
#  u'santaclara',
#  u'santaclarita',
#  u'santamaria',
#  u'santarosa',
#  u'savannah',
#  u'scottsdale',
#  u'seattle',
#  u'shreveport',
#  u'simivalley',
#  u'siouxfalls',
#  u'southbend',
#  u'spokane',
#  u'springfield',
#  u'stamford',
#  u'sterlingheights',
#  u'stlouis',
#  u'stockton',
#  u'stpetersburg',
#  u'sunnyvale',
#  u'surprise',
#  u'syracuse',
#  u'tacoma',
#  u'tallahassee',
#  u'tampa',
#  u'temecula',
#  u'tempe',
#  u'thornton',
#  u'thousandoaks',
#  u'toledo',
#  u'topeka',
#  u'torrance',
#  u'tucson',
#  u'tulsa',
#  u'tyler',
#  u'vallejo',
#  u'vancouver',
#  u'ventura',
#  u'victorville',
#  u'virginiabeach',
#  u'visalia',
#  u'vista',
#  u'waco',
#  u'warren',
#  u'washington',
#  u'waterbury',
#  u'westcovina',
#  u'westjordan',
#  u'westminster',
#  u'westpalmbeach',
#  u'westvalleycity',
#  u'wichita',
#  u'wichitafalls',
#  u'wilmington',
#  u'woodbridge',
#  u'worcester',
#  u'yonkers'}

# %%
# SCRAPE WIKIPEDIA FOR LARGEST US CITIES (NON-EXHAUSTIVE LIST)

# response = requests.get("https://en.wikipedia.org/wiki/List_of_mayors_of_the_50_largest_cities_in_the_United_States")
# HTML = response.text 
# response = requests.get('https://en.wikipedia.org/wiki/List_of_United_States_cities_by_population')
# HTML = response.text

# cities = Selector(text=HTML).xpath("//tr/td[2]//a/text()").extract()

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1.2 Only retain cities with properly formed ASCII
#
# Optionally, filter out any cities with impropper ASCII characters.  A smaller list will be easier to look at.  However you may not need to filter these if you spend more time scraping a more concise city list.  This list should help you narrow down the list of regional Craigslist sites.

# %%
# ONLY RETAIN PROPERLY FORMED CITIES WITH FILTERING FUNCTION

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2.  Write a function to capture current pricing information via Craigslist in one city.
# Choose a city from your scraped data, then go to the cooresponding city section on Craigslist, searching for "rv" in the auto section.  Write a method that pulls out the prices.

# %%
response = requests.get("http://sfbay.craigslist.org/search/rva")
HTML_craigslist = response.text 
HTML_craigslist[0:150]
# Out:
# u'\ufeff<!DOCTYPE html>\n\n<html class="no-js"><head>\n    <title>SF bay area recreational vehicles  - craigslist</title>\n\n    <meta name="description" content='

# %%
prices_sfbay = Selector(text=HTML_craigslist).xpath("//span[@class='l2']/span[@class='price']/text()").extract()
prices_sfbay
# Out:
# [u'$32995',
#  u'$13000',
#  u'$14999',
#  u'$53264',
#  u'$18900',
#  u'$109995',
#  u'$13999',
#  u'$2495',
#  u'$59995',
#  u'$11500',
#  u'$11500',
#  u'$41000',
#  u'$11500',
#  u'$11500',
#  u'$9500',
#  u'$75995',
#  u'$35950',
#  u'$26000',
#  u'$49995',
#  u'$26000',
#  u'$24000',
#  u'$11500',
#  u'$9200',
#  u'$11500',
#  u'$8500',
#  u'$9500',
#  u'$10500',
#  u'$94995',
#  u'$6000',
#  u'$16999',
#  u'$84995',
#  u'$49995',
#  u'$165293',
#  u'$179995',
#  u'$169995',
#  u'$159995',
#  u'$44995',
#  u'$59995',
#  u'$26400',
#  u'$24888',
#  u'$64995',
#  u'$99995',
#  u'$89995',
#  u'$89995',
#  u'$64995',
#  u'$119995',
#  u'$59995',
#  u'$64995',
#  u'$94995',
#  u'$52995',
#  u'$89995',
#  u'$32995',
#  u'$42995',
#  u'$12000',
#  u'$12000',
#  u'$159995',
#  u'$42995',
#  u'$44995',
#  u'$40',
#  u'$55900',
#  u'$19999',
#  u'$20995',
#  u'$4700',
#  u'$89995',
#  u'$85000',
#  u'$26400',
#  u'$41481',
#  u'$10999',
#  u'$35950',
#  u'$475',
#  u'$28999',
#  u'$82888',
#  u'$11500',
#  u'$29995',
#  u'$20',
#  u'$37250',
#  u'$98450',
#  u'$7200',
#  u'$12500']

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2.1 Create a mapping of cities to cooresponding regional Craigslist URLs
#
# Major US cities on Craigslist typically have their own cooresponding section (ie: SFBay Area, NYC, Boston, Miami, Seattle, etc).  Later, you will use these to query search results for various metropolitian regions listed on Craigslist.  Between the major metropolitan Craigslist sites, the only thing that will differ is the URL's that correspond to them.
#
# The point of the "mapping":  Create a data structure that allows you to iterate with both the name of the city from Wikipedia, with the cooresponding variable that that will allow you to construct each craigslist URL for each region.
#
# > For San Francsico (the Bay Area metropolitan area), the url for the RV search result is:
# > http://sfbay.craigslist.org/search/sss?query=rv
# >
# > The convention is http://[region].craigslist.org/search/sss?query=rf
# > Replacing [region] with the cooresponding city name will allow you to quickly iterate through each regional Craigslist site, and scrape the prices from the search results.  Keep this in mind while you build this "mapping".

# %%
def region(city):
    return 'http://' + city + '.craigslist.org/search/sss?query=rv' 

city_url = {}
for c in clean_cities:
    city_url[c] = region(c)
    
print city_url
# Out:
# {u'houston': u'http://houston.craigslist.org/search/sss?query=rv', u'madison': u'http://madison.craigslist.org/search/sss?query=rv', u'knoxville': u'http://knoxville.craigslist.org/search/sss?query=rv', u'cincinnati': u'http://cincinnati.craigslist.org/search/sss?query=rv', u'honolulu': u'http://honolulu.craigslist.org/search/sss?query=rv', u'fresno': u'http://fresno.craigslist.org/search/sss?query=rv', u'savannah': u'http://savannah.craigslist.org/search/sss?query=rv', u'beaumont': u'http://beaumont.craigslist.org/search/sss?query=rv', u'santaclarita': u'http://santaclarita.craigslist.org/search/sss?query=rv', u'alexandria': u'http://alexandria.craigslist.org/search/sss?query=rv', u'birmingham': u'http://birmingham.craigslist.org/search/sss?query=rv', u'frisco': u'http://frisco.craigslist.org/search/sss?query=rv', u'tallahassee': u'http://tallahassee.craigslist.org/search/sss?query=rv', u'montgomery': u'http://montgomery.craigslist.org/search/sss?query=rv', u'annarbor': u'http://annarbor.craigslist.org/search/sss?query=rv', u'warren': u'http://warren.craigslist.org/search/sss?query=rv', u'siouxfalls': u'http://siouxfalls.craigslist.org/search/sss?query=rv', u'newark': u'http://newark.craigslist.org/search/sss?query=rv', u'denton': u'http://denton.craigslist.org/search/sss?query=rv', u'fortwayne': u'http://fortwayne.craigslist.org/search/sss?query=rv', u'morenovalley
# 288      richardson  http://richardson.craigslist.org/search/sss?qu...
# 289       capecoral  http://capecoral.craigslist.org/search/sss?que...
# 290  westvalleycity  http://westvalleycity.craigslist.org/search/ss...
# 291         buffalo  http://buffalo.craigslist.org/search/sss?query=rv
#
# [292 rows x 2 columns]

# %%
# def extract_price(city_url_map):
#     for key, value in city_url_map.items():
#         print "For city: ", key
#         print "URL: ", value
        
# #         response = requests.get(url) 
# #         prices = Selector(text=response.text).xpath("//span[@class='price']/text()").extract()
        
# #         print prices
# #         print "==================================="
        
# extract_price(city_url)
# Out:
# For city:  houston
# URL:  http://houston.craigslist.org/search/sss?query=rv
# For city:  madison
# URL:  http://madison.craigslist.org/search/sss?query=rv
# For city:  elkgrove
# URL:  http://elkgrove.craigslist.org/search/sss?query=rv
# For city:  cincinnati
# URL:  http://cincinnati.craigslist.org/search/sss?query=rv
# For city:  honolulu
# URL:  http://honolulu.craigslist.org/search/sss?query=rv
# For city:  fresno
# URL:  http://fresno.craigslist.org/search/sss?query=rv
# For city:  savannah
# URL:  http://savannah.craigslist.org/search/sss?query=rv
# For city:  beaumont
# URL:  http://beaumont.craigslist.org/search/sss?query=rv
# For city:  santaclarita
# URL:  http://santaclarita.craigslist.org/search/sss?query=rv
# For city:  alexandria
# URL:  http://alexandria.craigslist.org/search/sss?query=rv
# For city:  birmingham
# URL:  http://birmingham.craigslist.org/search/sss?query=rv
# For city:  frisco
# URL:  http://frisco.craigslist.org/search/sss?query=rv
# For city:  tallahassee
# URL:  http://tallahassee.craigslist.org/search/sss?query=rv
# For city:  nevada
# URL:  http://nevada.craigslist.org/search/sss?query=rv
# For city:  annarbor
# URL:  http://annarbor.craigslist.org/search/sss?query=rv
# For city:  caguas
# URL:  http://caguas.craigslist.org/search/sss?query=rv
# For city:  warren
# URL:  http://warren.craigslist.org/search/sss?query=rv
# For city:  siouxfalls
# URL:  http://siouxfalls.craigslist.org/search/sss?query=rv
# For city:  newark
# URL:  http://newark.craigslist.org/search/sss?query=rv
# For city:  denton
# URL:  http://denton.craigslist.org/search/sss?query=rv
# For city:  fortwayne
# URL:  http://fortwayne.craigslist.org/search/sss?query=rv
# For city:  morenovalley
# URL:  http://morenovalley.craigslist.org/search/sss?query=rv
# For city:  macon
# URL:  http://macon.craigslist.org/search/sss?query=rv
# For city:  pembrokepines
# URL:  http://pembrokepines.craigslist.org/search/sss?query=rv
# For city:  fullerton
# URL:  http://fullerton.craigslist.org/search/sss?query=rv
# For city:  minnesota
# URL:  http://minnesota.craigslist.org/search/sss?query=rv
# For city:  denver
# URL:  http://denver.craigslist.org/search/sss?query=rv
# For city:  lansing
# URL:  http://lansing.craigslist.org/search/sss?query=rv
# For city:  sanantonio
# URL:  http://sanantonio.craigslist.org/search/sss?query=rv
# For city:  tyler
# URL:  http://tyler.craigslist.org/search/sss?query=rv
# For city:  sandysprings
# URL:  http://sandysprings.craigslist.org/search/sss?query=rv
# For city:  jerseycity
# URL:  http://jerseycity.craigslist.org/search/sss?query=rv
# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Define a function to caculate mean and median price per city.
#
# Now that you've created a list of cities you want to scrape, adapt your solution for grabbing data in one region site, to grab data for all regional sites that you collected, then calculate the mean and median price of RV results from each city.
#
# > Look at the URLs from a few different regions (ie: portland, phoenix, sfbay), and find what they have in common.  Determine the area in the URL string that needs to change the least, and figure out how to replace only that portion of the URL in order to iterate through each city.

# %%
# store into dictionaries so i can convert it into a dataframe
# for key, value in city_url.items():
    
#     city = key
    
#     try:
#         response = requests.get(value)

#         price = Selector(text=response.text).xpath("//span[@class='l2']/span[@class='price']/text()").extract()

#         cleaned_price = [float(x.replace('$','')) for x in price]


#         print city
#         print "Mean RV price: ", np.mean(cleaned_price)
#         print "Median Rv price: ", np.median(cleaned_price)
#         print "============================================"
#     except:
#         pass
# Out:
# houston
# Mean RV price:  34347.5
# Median Rv price:  17447.5
# ============================================
# madison
# Mean RV price:  9262.85714286
# Median Rv price:  2500.0
# ============================================
# cincinnati
# Mean RV price:  11826.3111111
# Median Rv price:  3250.0
# ============================================
# honolulu
# Mean RV price:  9886.24
# Median Rv price:  2700.0
# ============================================
# fresno
# Mean RV price:  25679.8539326
# Median Rv price:  25495.0
# ============================================
# savannah
# Mean RV price:  10387.9772727
# Median Rv price:  3250.0
# ============================================
# beaumont
# Mean RV price:  13937.5
# Median Rv price:  11375.0
# ============================================
# tallahassee
# Mean RV price:  20809.1744186
# Median Rv price:  8450.0
# ============================================
# annarbor
# Mean RV price:  10910.862069
# Median Rv price:  9500.0
# ============================================
# siouxfalls
# Mean RV price:  21306.9072165
# Median Rv price:  17900.0
# ============================================
# fortwayne
# Mean RV price:  7399.30337079
# Median Rv price:  3000.0
# ============================================
# macon
# Mean RV price:  24050.547619
# Median Rv price:  7497.5
# ============================================
# denver
# Mean RV price:  36258.0421053
# Median Rv price:  28998.0
# ============================================
# lansing
# Mean RV price:  13237.4578313
# Median Rv price:  12980.0
# ============================================
# sanantonio
# Mean RV price:  44409.25
# Median Rv price:  26567.5
# ============================================
# boulder
# Mean RV price:  11949.9259259
# Median Rv price:  6900.0
# ============================================
# tulsa
# Mean RV price:  38030.1529412
# Median Rv price:  24995.0
# ============================================
# washington
# Mean RV price:  11368.8837209
# Median Rv price:  337.5
# ============================================
# amarillo
# Mean RV price:  30350.9264706
# Median Rv price:  13200.0
# ============================================
# allentown
# Mean RV price:  10083.4047619
# Median Rv price:  4499.5
# ============================================
# vancouver
# Mean RV price:  12164.0444444
# Median Rv price:  295.0
# ============================================
# jacksonville
# Mean RV price:  13692.9213483
# Median Rv price:  449.0
# ============================================
# syracuse
# Mean RV price:  4600.0
# Median Rv price:  4600.0
# ============================================
# pueblo
# Mean RV price:  15640.6625
# Median Rv price:  11250.0
# ============================================
# lincoln
# Mean RV price:  27848.0555556
# Median Rv price:  28998.0
# ============================================
# norfolk
# Mean RV price:  11428.797619
# Median Rv price:  3499.5
# ============================================
# hartford
# Mean RV price:  8023.14
# Median Rv price:  450.0
# ============================================
# wilmington
# Mean RV price:  10406.0657895
# Median Rv price:  5750.0
# ============================================
# lexington
# Mean RV price:  39582.0574713
# Median Rv price:  9200.0
# ============================================
# detroit
# Mean RV price:  23189.0860215
# Median Rv price:  19999.0
# ============================================
# littlerock
# Mean RV price:  20485.9722222
# Median Rv price:  10300.0
# ============================================
# miami
# Mean RV price:  16725.4285714
# Median Rv price:  3617.0
# ============================================
# dallas
# Mean RV price:  24474.0
# Median Rv price:  20497.5
# ============================================
# laredo
# Mean RV price:  18803.890625
# Median Rv price:  9997.5
# ============================================
# milwaukee
# Mean RV price:  25019.0918367
# Median Rv price:  20782.5
# ============================================
# orlando
# Mean RV price:  47576.38
# Median Rv price:  27874.0
# ============================================
# lascruces
# Mean RV price:  20163.8791209
# Median Rv price:  15500.0
# ============================================
# losangeles
# Mean RV price:  29166.7619048
# Median Rv price:  20000.0
# ============================================
# provo
# Mean RV price:  36968.0208333
# Median Rv price:  21500.0
# ============================================
# cleveland
# Mean RV price:  10585.4216867
# Median Rv price:  6500.0
# ============================================
# portland
# Mean RV price:  32994.6666667
# Median Rv price:  26999.0
# ============================================
# batonrouge
# Mean RV price:  14095.9318182
# Median Rv price:  10999.5
# ============================================
# lancaster
# Mean RV price:  12260.9873418
# Median Rv price:  7495.0
# ============================================
# jackson
# Mean RV price:  28339.4489796
# Median Rv price:  24999.0
# ============================================
# chicago
# Mean RV price:  7205.7761194
# Median Rv price:  300.0
# ============================================
# delaware
# Mean RV price:  13794.0697674
# Median Rv price:  4195.0
# ============================================
# richmond
# Mean RV price:  12101.2906977
# Median Rv price:  2600.0
# ============================================
# stlouis
# Mean RV price:  24587.4222222
# Median Rv price:  20725.5
# ============================================
# santamaria
# Mean RV price:  25234.9078947
# Median Rv price:  24907.0
# ============================================
# toledo
# Mean RV price:  10804.9222222
# Median Rv price:  9499.5
# ============================================
# fargo
# Mean RV price:  25149.7717391
# Median Rv price:  17245.0
# ============================================
# philadelphia
# Mean RV price:  19741.2022472
# Median Rv price:  3000.0
# ============================================
# desmoines
# Mean RV price:  30854.1764706
# Median Rv price:  29995.0
# ============================================
# columbus
# Mean RV price:  9285.69148936
# Median Rv price:  1200.0
# ============================================
# newyork
# Mean RV price:  7686.62962963
# Median Rv price:  1095.0
# ============================================
# fortlauderdale
# Mean RV price:  16725.4285714
# Median Rv price:  3617.0
# ============================================
# nashville
# Mean RV price:  9736.42352941
# Median Rv price:  5885.0
# ============================================
# albuquerque
# Mean RV price:  36716.2962963
# Median Rv price:  9000.0
# ============================================
# boise
# Mean RV price:  14515.6129032
# Median Rv price:  7549.5
# ============================================
# phoenix
# Mean RV price:  28323.344086
# Median Rv price:  25000.0
# ============================================
# shreveport
# Mean RV price:  5745.36363636
# Median Rv price:  2300.0
# ============================================
# grandrapids
# Mean RV price:  25044.3855422
# Median Rv price:  675.0
# ============================================
# bakersfield
# Mean RV price:  39977.9295775
# Median Rv price:  24000.0
# ============================================
# sanfrancisco
# Mean RV price:  22773.8481013
# Median Rv price:  12490.0
# ============================================
# anchorage
# Mean RV price:  9482.07894737
# Median Rv price:  2000.0
# ============================================
# louisville
# Mean RV price:  118461.358974
# Median Rv price:  5000.0
# ============================================
# topeka
# Mean RV price:  26405.0
# Median Rv price:  17400.0
# ============================================
# raleigh
# Mean RV price:  9716.92647059
# Median Rv price:  2500.0
# ============================================
# austin
# Mean RV price:  38726.8823529
# Median Rv price:  24988.0
# ============================================
# baltimore
# Mean RV price:  22738.5393258
# Median Rv price:  2000.0
# ============================================
# fortcollins
# Mean RV price:  3252.73255814
# Median Rv price:  249.0
# ============================================
# hampton
# Mean RV price:  11428.797619
# Median Rv price:  3499.5
# ============================================
# stockton
# Mean RV price:  13214.4477612
# Median Rv price:  650.0
# ============================================
# neworleans
# Mean RV price:  14271.1666667
# Median Rv price:  5000.0
# ============================================
# clarksville
# Mean RV price:  12848.7213115
# Median Rv price:  5899.0
# ============================================
# providence
# Mean RV price:  11224.7846154
# Median Rv price:  150.0
# ============================================
# boston
# Mean RV price:  8651.3372093
# Median Rv price:  425.0
# ============================================
# evansville
# Mean RV price:  15075.4269663
# Median Rv price:  5600.0
# ============================================
# odessa
# Mean RV price:  11691.0428571
# Median Rv price:  3600.0
# ============================================
# pittsburgh
# Mean RV price:  8877.38372093
# Median Rv price:  5950.0
# ============================================
# peoria
# Mean RV price:  13971.2747253
# Median Rv price:  4825.0
# ============================================
# minneapolis
# Mean RV price:  19974.7529412
# Median Rv price:  17161.0
# ============================================
# saltlakecity
# Mean RV price:  38565.5
# Median Rv price:  21997.5
# ============================================
# spokane
# Mean RV price:  20038.2
# Median Rv price:  23990.0
# ============================================
# atlanta
# Mean RV price:  34064.8648649
# Median Rv price:  6500.0
# ============================================
# memphis
# Mean RV price:  19848.8690476
# Median Rv price:  4797.0
# ============================================
# lasvegas
# Mean RV price:  28611.2285714
# Median Rv price:  21995.0
# ============================================
# tampa
# Mean RV price:  38154.29
# Median Rv price:  27874.0
# ============================================
# rockford
# Mean RV price:  13578.2702703
# Median Rv price:  6097.5
# ============================================
# montgomery
# Mean RV price:  19386.0
# Median Rv price:  13995.0
# ============================================
# sandiego
# Mean RV price:  13629.8133333
# Median Rv price:  300.0
# ============================================
# oklahomacity
# Mean RV price:  35435.5714286
# Median Rv price:  32496.0
# ============================================
# sanangelo
# Mean RV price:  19264.0
# Median Rv price:  5500.0
# ============================================
# modesto
# Mean RV price:  10569.8461538
# Median Rv price:  6500.0
# ============================================
# augusta
# Mean RV price:  14538.4177215
# Median Rv price:  5995.0
# ============================================
# mobile
# Mean RV price:  19546.2125
# Median Rv price:  11000.0
# ============================================
# tucson
# Mean RV price:  43197.8888889
# Median Rv price:  37445.0
# ============================================
# waco
# Mean RV price:  nan
# Median Rv price:  nan
# ============================================
# knoxville
# Mean RV price:  23729.5443038
# Median Rv price:  16900.0
# ============================================
# wichita
# Mean RV price:  20847.4166667
# Median Rv price:  17500.0
# ============================================
# charlotte
# Mean RV price:  9274.51162791
# Median Rv price:  555.0
# ============================================
# collegestation
# Mean RV price:  10148.952381
# Median Rv price:  3647.5
# ============================================
# worcester
# Mean RV price:  9927.9137931
# Median Rv price:  1249.0
# ============================================
# reno
# Mean RV price:  6066.98113208
# Median Rv price:  300.0
# ============================================
# visalia
# Mean RV price:  47119.94
# Median Rv price:  5500.0
# ============================================
# salem
# Mean RV price:  184121.8
# Median Rv price:  250.0
# ============================================
# elpaso
# Mean RV price:  39681.8172043
# Median Rv price:  13500.0
# ============================================
# springfield
# Mean RV price:  13691.7875
# Median Rv price:  978.5
# ============================================
# seattle
# Mean RV price:  35979.1041667
# Median Rv price:  26997.0
# ============================================
# newhaven
# Mean RV price:  6472.21176471
# Median Rv price:  2800.0
# ============================================
# rochester
# Mean RV price:  nan
# Median Rv price:  nan
# ============================================
# abilene
# Mean RV price:  nan
# Median Rv price:  nan
# ============================================
# lubbock
# Mean RV price:  11796.6666667
# Median Rv price:  4350.0
# ============================================
# wichitafalls
# Mean RV price:  nan
# Median Rv price:  nan
# ============================================
# gainesville
# Mean RV price:  19804.3614458
# Median Rv price:  4499.0
# ============================================
# mcallen
# Mean RV price:  8887.05714286
# Median Rv price:  5500.0
# ============================================
# huntsville
# Mean RV price:  12696.1827957
# Median Rv price:  6800.0
# ============================================
# clovis
# Mean RV price:  21198.3714286
# Median Rv price:  16999.0
# ============================================
# eugene
# Mean RV price:  37399.5
# Median Rv price:  38350.0
# ============================================
# kansascity
# Mean RV price:  34074.3030303
# Median Rv price:  33995.0
# ============================================
# sacramento
# Mean RV price:  39532.7653061
# Median Rv price:  47999.0
# ============================================
# indianapolis
# Mean RV price:  6632.67058824
# Median Rv price:  2000.0
# ============================================
# columbia
# Mean RV price:  25039.9310345
# Median Rv price:  8995.0
# ============================================
# dayton
# Mean RV price:  13735.0898876
# Median Rv price:  4500.0
# ============================================
# brownsville
# Mean RV price:  10305.2794118
# Median Rv price:  4147.5
# ============================================
# charleston
# Mean RV price:  8612.51470588
# Median Rv price:  250.0
# ============================================
# southbend
# Mean RV price:  6289.36842105
# Median Rv price:  375.0
# ============================================
# fayetteville
# Mean RV price:  6299.41025641
# Median Rv price:  3737.0
# ============================================
# manchester
# Mean RV price:  nan
# Median Rv price:  nan
# ============================================
# westpalmbeach
# Mean RV price:  16725.4285714
# Median Rv price:  3617.0
# ============================================
# greenbay
# Mean RV price:  10616.308642
# Median Rv price:  8995.0
# ============================================
# chattanooga
# Mean RV price:  19205.6091954
# Median Rv price:  9999.0
# ============================================
# ventura
# Mean RV price:  38697.3561644
# Median Rv price:  7800.0
# ============================================
# omaha
# Mean RV price:  33114.1904762
# Median Rv price:  32897.0
# ============================================
# killeen
# Mean RV price:  5335.9
# Median Rv price:  387.5
# ============================================
# lakeland
# Mean RV price:  14374.1969697
# Median Rv price:  2429.0
# ============================================
# newjersey
# Mean RV price:  13730.0609756
# Median Rv price:  3697.5
# ============================================
# corpuschristi
# Mean RV price:  24900.0
# Median Rv price:  24900.0
# ============================================
# lafayette
# Mean RV price:  14302.1044776
# Median Rv price:  15995.0
# ============================================
# greensboro
# Mean RV price:  11089.6071429
# Median Rv price:  3340.0
# ============================================
# buffalo
# Mean RV price:  10147.6144578
# Median Rv price:  150.0
# ============================================

# %%
city_price = {}
city_mean_median = {}
for key, value in city_url.items():
    
    city = key
    
    try:
        response = requests.get(value)

        price = Selector(text=response.text).xpath("//span[@class='l2']/span[@class='price']/text()").extract()

        cleaned_price = [float(x.replace('$','')) for x in price]
        city_price[city] = cleaned_price
        
        mean = np.mean(cleaned_price)
        med = np.median(cleaned_price)
        city_mean_median[city] = [mean, med]
        
    except:
         pass
# Out:
# /Users/amos/anaconda/envs/dsi/lib/python2.7/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
city_mean_median
# Out:
# {u'abilene': [8500.0, 8500.0],
#  u'albuquerque': [37119.707317073167, 15947.5],
#  u'allentown': [11628.535714285714, 5747.0],
#  u'amarillo': [29635.492957746479, 15500.0],
#  u'anchorage': [9586.0263157894733, 1925.0],
#  u'annarbor': [11590.744444444445, 9997.5],
#  u'atlanta': [35531.118421052633, 8247.5],
#  u'augusta': [13138.375, 5995.0],
#  u'austin': [40831.199999999997, 24988.0],
#  u'bakersfield': [45366.478873239437, 37900.0],
#  u'baltimore': [22672.527472527472, 2150.0],
#  u'batonrouge': [14242.974358974359, 10000.0],
#  u'beaumont': [11750.0, 10500.0],
#  u'billings': [23181.534246575342, 10000.0],
#  u'boise': [15956.968253968254, 9999.0],
#  u'boston': [8196.1445783132531, 350.0],
#  u'boulder': [8367.3333333333339, 1900.0],
#  u'brownsville': [12105.205882352941, 4000.0],
#  u'buffalo': [10150.759036144578, 150.0],
#  u'cedarrapids': [19236.10465116279, 9750.0],
#  u'charleston': [7947.7857142857147, 275.0],
#  u'charlotte': [9291.6627906976737, 580.0],
#  u'chattanooga': [18684.045454545456, 9347.5],
#  u'chicago': [6329.3432835820895, 159.0],
#  u'cincinnati': [12378.6, 4125.0],
#  u'clarksville': [12677.096774193549, 5547.0],
#  u'cleveland': [10483.595238095239, 6497.5],
#  u'clovis': [21258.225352112677, 16999.0],
#  u'collegestation': [10060.058823529413, 2997.5],
#  u'columbia': [24508.134146341465, 8947.5],
#  u'columbus': [9262.8191489361707, 1050.0],
#  u'corpuschristi': [nan, nan],
#  u'dallas': [23993.136363636364, 19995.0],
#  u'dayton': [13777.839080459769, 3850.0],
#  u'denver': [39354.81443298969, 32998.0],
#  u'desmoines': [30743.890625, 29995.0],
#  u'detroit': [21723.698924731183, 19999.0],
#  u'elpaso': [43288.06451612903, 16999.0],
#  u'eugene': [37399.5, 38350.0],
#  u'evansville': [14932.348314606741, 5495.0],
#  u'fargo': [25462.817204301075, 17495.0],
#  u'fayetteville': [5873.7435897435898, 3495.5],
#  u'fortcollins': [2609.9294117647059, 249.0],
#  u'fortlauderdale': [15889.722891566265, 4000.0],
#  u'salem': [178285.08510638299, 300.0],
#  u'saltlakecity': [39278.939759036148, 23995.0],
#  u'sanangelo': [19264.0, 5500.0],
#  u'sanantonio': [40360.857142857145, 26900.0],
#  u'sandiego': [23397.119999999999, 400.0],
#  u'sanfrancisco': [28262.772151898735, 19999.0],
#  u'santamaria': [23854.093333333334, 23999.0],
#  u'savannah': [10733.674157303371, 4100.0],
#  u'seattle': [31863.799999999999, 25995.0],
#  u'shreveport': [6318.8999999999996, 2397.5],
#  u'siouxfalls': [20371.505263157895, 17500.0],
#  u'southbend': [6856.413333333333, 425.0],
#  u'spokane': [44883.5, 44883.5],
#  u'springfield': [13204.679012345679, 2000.0],
#  u'stlouis': [24110.684782608696, 20462.0],
#  u'stockton': [14347.281690140846, 900.0],
#  u'syracuse': [4600.0, 4600.0],
#  u'tallahassee': [21811.80459770115, 8500.0],
#  u'tampa': [40381.57, 27874.0],
#  u'toledo': [11136.681818181818, 9999.0],
#  u'topeka': [21669.744186046511, 10999.5],
#  u'tucson': [42252.683673469386, 37445.0],
#  u'tulsa': [36807.88636363636, 23439.5],
#  u'vancouver': [12022.865168539325, 220.0],
#  u'ventura': [37387.493150684932, 7700.0],
#  u'visalia': [47418.900000000001, 5500.0],
#  u'waco': [nan, nan],
#  u'washington': [8310.6292134831456, 689.0],
#  u'westpalmbeach': [15889.722891566265, 4000.0],
#  u'wichita': [21128.6875, 18250.0],
#  u'wichitafalls': [nan, nan],
#  u'wilmington': [10766.453333333333, 5900.0],
#  u'worcester': [14444.629032258064, 2942.5]}

# %%
for key, value in city_price.items():
    if len(value) < 4:
        print city_price.pop(key, None)
# Out:
# [4600.0]
# []
# [1.0, 89766.0]
# []
# [49788.0, 5500.0, 2504.0]
# []
# []
# [8500.0]
# []

# %%
bad_columns = [u'syracuse',
 u'manchester',
 u'spokane',
 u'waco',
 u'sanangelo',
 u'rochester',
 u'wichitafalls',
 u'abilene',
 u'corpuschristi']

for b in bad_columns:
    print b, city_mean_median.pop(b, None)
# Out:
# syracuse [4600.0, 4600.0]
# manchester [nan, nan]
# spokane [44883.5, 44883.5]
# waco [nan, nan]
# sanangelo [19264.0, 5500.0]
# rochester [nan, nan]
# wichitafalls [nan, nan]
# abilene [8500.0, 8500.0]
# corpuschristi [nan, nan]

# %%
print len(city_mean_median), len(city_price)
# Out:
#  132 132

# %%
df_city_list_price = pd.DataFrame(city_price.items(), columns=['city', 'rv_prices'])
# df_city_mean_median = pd.DataFrame(city_mean_median.items(), columns=['city', 'rv_mean_median_price'])
df_city_price.head()
# Out:
#          city                                          rv_prices
# 0     houston  [600.0, 17995.0, 1.0, 12988.0, 17995.0, 16900....
# 1     madison  [19988.0, 15988.0, 15988.0, 12700.0, 9999.0, 1...
# 2  cincinnati  [24400.0, 16995.0, 18000.0, 19765.0, 42990.0, ...
# 3      fresno  [17851.0, 28138.0, 37978.0, 16995.0, 43393.0, ...
# 4    savannah  [100.0, 400.0, 1800.0, 2314.0, 17500.0, 10.0, ...

# %%
# city_dict_price = {}
# for key,value in city_price.iteritems():
#     for i in value:
#         city_dict_price[key] = i
        
# city_dict_price

df_city_price.transpose()
# Out:
#                                                          0    \
# city                                                 houston
# rv_prices  [600.0, 17995.0, 1.0, 12988.0, 17995.0, 16900....
#
#                                                          1    \
# city                                                 madison
# rv_prices  [19988.0, 15988.0, 15988.0, 12700.0, 9999.0, 1...
#
#                                                          2    \
# city                                              cincinnati
# rv_prices  [24400.0, 16995.0, 18000.0, 19765.0, 42990.0, ...
#
#                                                          3    \
# city                                                  fresno
# rv_prices  [17851.0, 28138.0, 37978.0, 16995.0, 43393.0, ...
#
#                                                          4    \
# city                                                savannah
# rv_prices  [100.0, 400.0, 1800.0, 2314.0, 17500.0, 10.0, ...
#
#                                                    5    \
# city                                          beaumont
# rv_prices  [3000.0, 28000.0, 12250.0, 5000.0, 10500.0]
#
#                                                          6    \
# city                                                 hampton
# rv_prices  [22500.0, 21500.0, 425.0, 3400.0, 3499.0, 50.0...
#
#                                                          7    \
# city                                             tallahassee
# rv_prices  [44750.0, 16874.0, 300.0, 10499.0, 20000.0, 85...
#
#                                                          8    \
# city                                                 modesto
# rv_prices  [27995.0, 9500.0, 12500.0, 6500.0, 70.0, 200.0...
#
#                                                          9    \
# city                                               milwaukee
# rv_prices  [31988.0, 19988.0, 13588.0, 24988.0, 9995.0, 1...
#
#                                  ...                          \
# city                             ...
# rv_prices                        ...
#
#                                                          131  \
# city                                                  mobile
# rv_prices  [3900.0, 1500.0, 137.0, 1800.0, 6300.0, 1.0, 3...
#
#                                                          132       133  \
# city                                                lakeland   abilene
# rv_prices  [25404.0, 169000.0, 25658.0, 41690.0, 73196.0,...  [8500.0]
#
#                                                          134            135  \
# city                                                 wichita  corpuschristi
# rv_prices  [29000.0, 16995.0, 22000.0, 21980.0, 13980.0, ...             []
#
#                                                          136  \
# city                                               lafayette
# rv_prices  [22995.0, 18995.0, 15995.0, 22099.0, 7800.0, 1...
#
#                                                          137  \
# city                                             brownsville
# rv_prices  [2400.0, 1.0, 300.0, 6990.0, 1.0, 72999.0, 400...
#
#                                                          138  \
# city                                               allentown
# rv_prices  [77.0, 120.0, 4600.0, 8500.0, 500.0, 125.0, 40...
#
#                                                          139  \
# city                                            fayetteville
# rv_prices  [3207.0, 3330.0, 2602.0, 565.0, 8200.0, 500.0,...
#
#                                                          140
# city                                                 buffalo
# rv_prices  [4600.0, 550.0, 450.0, 450.0, 35.0, 50.0, 2899...
#
# [2 rows x 141 columns]

# %%
df_nonlist_price = pd.DataFrame.from_dict(city_price, orient='index').transpose()
df_nonlist_price.head()
# Out:
#    houston  madison  cincinnati   fresno  savannah  beaumont  hampton  \
# 0    600.0  19988.0     24400.0  17851.0     100.0    3000.0  22500.0
# 1  17995.0  15988.0     16995.0  28138.0     400.0   28000.0  21500.0
# 2      1.0  15988.0     18000.0  37978.0    1800.0   12250.0    425.0
# 3  12988.0  12700.0     19765.0  16995.0    2314.0    5000.0   3400.0
# 4  17995.0   9999.0     42990.0  43393.0   17500.0   10500.0   3499.0
#
#    tallahassee  modesto  milwaukee   ...       omaha  killeen  mobile  \
# 0      44750.0  27995.0    31988.0   ...     63998.0    400.0  3900.0
# 1      16874.0   9500.0    19988.0   ...     51999.0    375.0  1500.0
# 2        300.0  12500.0    13588.0   ...     24999.0    375.0   137.0
# 3      10499.0   6500.0    24988.0   ...     71999.0     75.0  1800.0
# 4      20000.0     70.0     9995.0   ...     32999.0     65.0  6300.0
#
#    lakeland  wichita  lafayette  brownsville  allentown  fayetteville  buffalo
# 0   25404.0  29000.0    22995.0       2400.0       77.0        3207.0   4600.0
# 1  169000.0  16995.0    18995.0          1.0      120.0        3330.0    550.0
# 2   25658.0  22000.0    15995.0        300.0     4600.0        2602.0    450.0
# 3   41690.0  21980.0    22099.0       6990.0     8500.0         565.0    450.0
# 4   73196.0  13980.0     7800.0          1.0      500.0        8200.0     35.0
#
# [5 rows x 132 columns]

# %%
# bad_columns = []
# df_price.isnull().sum()
# for col in df_price.columns:
#     if df_price[col].isnull().sum() > 95:
#         bad_columns.append(col)
        
# bad_columns


    
    

# Create a function to where if count of nan values is greater than the number of columns than return ???
# using apply, map
# Out:
# [u'syracuse',
#  u'manchester',
#  u'spokane',
#  u'waco',
#  u'sanangelo',
#  u'rochester',
#  u'wichitafalls',
#  u'abilene',
#  u'corpuschristi']

# %%
# for col in bad_columns:
#     print df_price[col].isnull().sum()
# Out:
# 99
# 100
# 98
# 100
# 97
# 100
# 100
# 99
# 100

# %%
# 1. create comparison between major cities and surrounding smaller cities
# i assume major city rv prices are a bit higher than smaller city rv prices. 

# 2. california cities vs all other states
# 3. 


df_price.shape
# Out:
# (100, 141)

# %%
df_city_mean_median = pd.DataFrame.from_dict(city_mean_median, orient='index')
df_city_mean_median.rename(columns={0:'mean_price', 1:'median_price'}, inplace=True)
df_city_mean_median
# Out:
#                   mean_price  median_price
# houston         21121.750000       14944.0
# madison         12239.426966        5488.0
# cincinnati      12378.600000        4125.0
# fresno          27196.710843       25495.0
# savannah        10733.674157        4100.0
# beaumont        11750.000000       10500.0
# hampton         11060.851852        3000.0
# tallahassee     21811.804598        8500.0
# modesto         10569.846154        6500.0
# milwaukee       23245.141414       19988.0
# mcallen          9203.434783        5000.0
# annarbor        11590.744444        9997.5
# siouxfalls      20371.505263       17500.0
# fortwayne        7131.136364        3197.0
# providence      10588.609375          82.5
# clarksville     12677.096774        5547.0
# denver          39354.814433       32998.0
# lansing         11584.518072       10495.0
# sanantonio      40360.857143       26900.0
# clovis          21258.225352       16999.0
# eugene          37399.500000       38350.0
# boulder          8367.333333        1900.0
# sanfrancisco    28262.772152       19999.0
# tulsa           36807.886364       23439.5
# amarillo        29635.492958       15500.0
# jacksonville    13693.943820         449.0
# pueblo          17817.641026       17995.0
# lincoln         27848.055556       28998.0
# norfolk         11060.851852        3000.0
# miami           15889.722892        4000.0
# ...                      ...           ...
# newhaven         6622.416667        3050.0
# dallas          23993.136364       19995.0
# lubbock         13921.000000        6400.0
# gainesville     20611.215909        4200.0
# montgomery      20092.781818       11350.0
# huntsville      11633.868132        6800.0
# louisville     119382.653846        5700.0
# vancouver       12022.865169         220.0
# springfield     13204.679012        2000.0
# greensboro      11069.440476        3450.0
# indianapolis     6632.523810        2000.0
# columbia        24508.134146        8947.5
# phoenix         28870.223404       26230.0
# dayton          13777.839080        3850.0
# sacramento      38722.295918       47999.0
# littlerock      23099.676471       13000.0
# charleston       7947.785714         275.0
# billings        23181.534247       10000.0
# westpalmbeach   15889.722892        4000.0
# chattanooga     18684.045455        9347.5
# omaha           32129.876923       32890.0
# killeen          5650.000000         375.0
# mobile          19932.480000        7950.0
# lakeland        14364.569231        2254.0
# wichita         21128.687500       18250.0
# lafayette       13335.527273       10985.0
# brownsville     12105.205882        4000.0
# allentown       11628.535714        5747.0
# fayetteville     5873.743590        3495.5
# buffalo         10150.759036         150.0
#
# [132 rows x 2 columns]

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Run your scraping process, and save your results to a CSV file.

# %%
df_city_mean_median.to_csv(path_or_buf='/Users/amos/Desktop/rv_city_mean_median.csv')

# %%
df_nonlist_price.to_csv(path_or_buf='/Users/amos/Desktop/rv_city_prices.csv')

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Do an analysis of the RV market.
#
# Go head we'll wait.  Anything notable about the data?

# %%
df_price = df_nonlist_price
df_price.head()
# Out:
#    houston  madison  cincinnati   fresno  savannah  beaumont  hampton  \
# 0    600.0  19988.0     24400.0  17851.0     100.0    3000.0  22500.0
# 1  17995.0  15988.0     16995.0  28138.0     400.0   28000.0  21500.0
# 2      1.0  15988.0     18000.0  37978.0    1800.0   12250.0    425.0
# 3  12988.0  12700.0     19765.0  16995.0    2314.0    5000.0   3400.0
# 4  17995.0   9999.0     42990.0  43393.0   17500.0   10500.0   3499.0
#
#    tallahassee  modesto  milwaukee   ...       omaha  killeen  mobile  \
# 0      44750.0  27995.0    31988.0   ...     63998.0    400.0  3900.0
# 1      16874.0   9500.0    19988.0   ...     51999.0    375.0  1500.0
# 2        300.0  12500.0    13588.0   ...     24999.0    375.0   137.0
# 3      10499.0   6500.0    24988.0   ...     71999.0     75.0  1800.0
# 4      20000.0     70.0     9995.0   ...     32999.0     65.0  6300.0
#
#    lakeland  wichita  lafayette  brownsville  allentown  fayetteville  buffalo
# 0   25404.0  29000.0    22995.0       2400.0       77.0        3207.0   4600.0
# 1  169000.0  16995.0    18995.0          1.0      120.0        3330.0    550.0
# 2   25658.0  22000.0    15995.0        300.0     4600.0        2602.0    450.0
# 3   41690.0  21980.0    22099.0       6990.0     8500.0         565.0    450.0
# 4   73196.0  13980.0     7800.0          1.0      500.0        8200.0     35.0
#
# [5 rows x 132 columns]

# %%
df_price.columns
# Out:
# Index([u'houston', u'madison', u'cincinnati', u'fresno', u'savannah',
#        u'beaumont', u'hampton', u'tallahassee', u'modesto', u'milwaukee',
#        ...
#        u'omaha', u'killeen', u'mobile', u'lakeland', u'wichita', u'lafayette',
#        u'brownsville', u'allentown', u'fayetteville', u'buffalo'],
#       dtype='object', length=132)

# %%
# replace outliers in price with nan values. Assuming any RV < 5,000 is not worth reselling 
for col in df_price.columns:
    df_price[col] = df_price[col].map(lambda x: np.nan if x < 5000 else x)
    
df_price.describe()
# Out:
#             madison     cincinnati        fresno      savannah       hampton  \
# count     46.000000      44.000000     77.000000     42.000000     34.000000
# mean   23149.804348   24700.000000  29284.766234  20914.738095  25301.264706
# std    13834.031628   25574.472061  12792.307851  13572.013879  19606.207793
# min     5000.000000    5000.000000  12995.000000   5300.000000   5999.000000
# 25%             NaN            NaN           NaN           NaN           NaN
# 50%             NaN            NaN           NaN           NaN           NaN
# 75%             NaN            NaN           NaN           NaN           NaN
# max    74500.000000  159000.000000  63603.000000  60000.000000  80000.000000
#
#          tallahassee       modesto     milwaukee      mcallen      annarbor  \
# count      49.000000     14.000000     99.000000     35.00000     53.000000
# mean    37862.081633  19323.928571  23245.141414  16042.80000  19028.245283
# std     35110.655798  15630.969159  11955.679817  10614.34591  11018.630665
# min      5200.000000   6500.000000   8495.000000   5000.00000   5900.000000
# 25%              NaN           NaN           NaN          NaN           NaN
# 50%              NaN           NaN           NaN          NaN           NaN
# 75%              NaN           NaN           NaN          NaN           NaN
# max    179000.000000  61500.000000  69995.000000  49788.00000  75000.000000
#
#            ...         chattanooga          omaha         mobile  \
# count      ...           56.000000      49.000000      44.000000
# mean       ...        29030.589286   42369.571429   33203.113636
# std        ...        43097.469037   37321.720690   26343.067557
# min        ...         5000.000000    7300.000000    5900.000000
# 25%        ...                 NaN            NaN            NaN
# 50%        ...                 NaN            NaN            NaN
# 75%        ...                 NaN            NaN            NaN
# max        ...       325000.000000  275000.000000  129995.000000
#
#             lakeland        wichita     lafayette    brownsville  \
# count      23.000000      74.000000     34.000000      32.000000
# mean    38400.652174   27234.648649  20866.323529   23522.562500
# std     34838.033835   35066.771189   9698.303453   27595.162671
# min     11499.000000    5500.000000   5500.000000    5000.000000
# 25%              NaN            NaN           NaN            NaN
# 50%              NaN            NaN           NaN            NaN
# 75%              NaN            NaN           NaN            NaN
# max    169000.000000  275000.000000  49500.000000  129995.000000
#
#            allentown  fayetteville       buffalo
# count      43.000000       25.0000     23.000000
# mean    21366.255814    13024.6000  35574.347826
# std     22077.361303    10579.8068  27956.475870
# min      5495.000000     5025.0000   5000.000000
# 25%              NaN           NaN           NaN
# 50%              NaN           NaN           NaN
# 75%              NaN           NaN           NaN
# max    129995.000000    42000.0000  89999.000000
#
# [8 rows x 125 columns]

# %%
# Drop columns that contain 75% nan values 
for col in df_price.columns:
    if df_price[col].isnull().sum() > .75 * df_price.shape[0]:
        df_price.drop(col, axis=1, inplace=True)

# %%
df = df_price.T
df['mean'] = df.apply(np.mean,axis=1)
df.head()
# Out:
#                   0        1        2        3        4        5        6  \
# madison     19988.0  15988.0  15988.0  12700.0   9999.0      NaN      NaN
# cincinnati  24400.0  16995.0  18000.0  19765.0  42990.0  18750.0   5500.0
# fresno      17851.0  28138.0  37978.0  16995.0  43393.0  18995.0  25534.0
# savannah        NaN      NaN      NaN      NaN  17500.0      NaN  60000.0
# hampton     22500.0  21500.0      NaN      NaN      NaN      NaN      NaN
#
#                   7        8        9      ...       91  92  93  94  95  96  \
# madison         NaN      NaN  52500.0      ...      NaN NaN NaN NaN NaN NaN
# cincinnati      NaN  29995.0  11000.0      ...      NaN NaN NaN NaN NaN NaN
# fresno      28138.0  18995.0  24995.0      ...      NaN NaN NaN NaN NaN NaN
# savannah        NaN      NaN      NaN      ...      NaN NaN NaN NaN NaN NaN
# hampton         NaN      NaN      NaN      ...      NaN NaN NaN NaN NaN NaN
#
#             97  98  99          mean
# madison    NaN NaN NaN  23149.804348
# cincinnati NaN NaN NaN  24700.000000
# fresno     NaN NaN NaN  29284.766234
# savannah   NaN NaN NaN  20914.738095
# hampton    NaN NaN NaN  25301.264706
#
# [5 rows x 101 columns]

# %%
df_only_mean = df[['mean']]
df_only_mean.head()
# Out:
#                     mean
# madison     23149.804348
# cincinnati  24700.000000
# fresno      29284.766234
# savannah    20914.738095
# hampton     25301.264706

# %%
print df_only_mean.max()
print df_only_mean.idxmin(), df_only_mean.loc['fayetteville']
# Out:
# mean    220815.285714
# dtype: float64
# mean    fayetteville
# dtype: object mean    13024.6
# Name: fayetteville, dtype: float64

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 5.1 Does it makes sense to buy RVs in one region and sell them in another?
#
# Assuming the cost of shipping or driving from one regional market to another.

# %%
print  df_only_mean.idxmax()[0], "has the highest average RV price of: $%f" % df_only_mean.max()[0]
print  df_only_mean.idxmin()[0], "has the lowest average RV price of: $%f" % df_only_mean.min()[0]
# Out:
# louisville has the highest average RV price of: $220815.285714
# fayetteville has the lowest average RV price of: $13024.600000

# %% [markdown]
# # Excluding transportation costs: Buying from Louisville and selling in Fayetteville will yield the greatest profit

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 5.2 Can you pull out the "make" from the markup and include that in your analyis?
# How reliable is this data and does it make sense?

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 5.3 Are there any other variables you could pull out of the markup to help describe your dataset?

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 6. Move your project into scrapy (if you haven't used Scrapy yet)
#
# >Start a project by using the command `scrapy startproject [projectname]`
# > - Update your settings.py (review our past example)
# > - Update your items.py
# > - Create a spiders file in your `[project_name]/[project_name]/spiders` directory
#
# You can update your spider class with the complete list of craigslist "start urls" to effectively scrape all of the regions.  Start with one to test.
#
# Updating your parse method with the method you chose should require minimal changes.  It will require you to update your parse method to use the response parameter, and an item model (defined in items.py).

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7.  Chose another area of Craigslist to scrape.
#
# **Choose an area having more than a single page of results, then scrape multiple regions, multiple pages of search results and or details pages.**
#
# This is the true exercise of being able to understand how to succesffuly plan, develop, and employ a broader scraping strategy.  Even though this seems like a challenging task, a few tweeks of your current code can make this very managable if you've pieced together all the touch points.  If you are still confused as to some of the milestones within this process, this is an excellent opportunity to round out your understanding, or help you build a list of questions to fill in your gaps.
#
# _Use Scrapy!  Provide your code in this project directory when you submit this project._
